# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets,transforms
import time
from torch.utils.tensorboard import SummaryWriter
import os
import matplotlib.pyplot as plt
os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"

# %% [markdown]
# ## 设定参数与CIFAR-10数据集加载

# %%
BATCH_SIZE = 200 
EPOCH = 75
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
train_set = datasets.CIFAR10("datasets",train = True,download = True,
                            transform = transforms.Compose([
                                transforms.ToTensor(),
                                transforms.Normalize((0.4914, 0.4822, 0.4465), (0.247, 0.243, 0.261))
                            ]))
# Out:
# Files already downloaded and verified

# %%
test_set = datasets.CIFAR10("datasets",train = False,download = True,
                           transform = transforms.Compose([
                               transforms.ToTensor(),
                               transforms.Normalize((0.4914, 0.4822, 0.4465), (0.247, 0.243, 0.261))
                           ]))
# Out:
# Files already downloaded and verified

# %%
train_loader = torch.utils.data.DataLoader(train_set,batch_size = BATCH_SIZE,shuffle = True)
test_loader = torch.utils.data.DataLoader(test_set,batch_size = BATCH_SIZE,shuffle = True)

# %%
len(train_set),len(test_set),len(train_loader),len(test_loader)
# Out:
# (50000, 10000, 250, 50)

# %% [markdown]
# ## 训练与测试函数

# %%
def train(net,device,train_loader,optimizer,epoch,LOSS):#输入中的LOSS用于记录每次的LOSS值
    n_iter = 0
    net.train()
    for i,(data,target) in enumerate(train_loader):
        Loss = []
        n_iter += 1
        #这个循环走 250 次，一次有200个数据被训练
        data,target = data.to(device),target.to(device)
        optimizer.zero_grad()
        output = net(data)
        loss = criterion(output,target).to(device)
        loss.backward()
        Loss.append(loss.item())
        LOSS.append(loss.item())
        optimizer.step()
        #每 50 次输出一次结果
        if n_iter % 125 == 0: 
            print("Trian Epoch",epoch,(i+1)*len(data),"/",len(train_loader.dataset),end = " ")
            print("LOSS:{:.4f}".format(sum(Loss)/len(Loss)))

# %%
def test(net,device,test_loader,ACC):#输入中的ACC用于记录每次测试的测试精度
    net.eval()
    n_iter = 0
    correct = 0
    with torch.no_grad():
        for data,target in test_loader:
            n_iter += 1
            data,target = data.to(device),target.to(device)
            output = net(data)
            _,predicted = torch.max(output.data,1)
            correct +=(predicted == target).sum().item()
    ACC.append(100.0*correct/len(test_loader.dataset))
    print("Accuracy on test iamges:{:.3f}%".format(100.0*correct/len(test_loader.dataset)))

# %% [markdown]
# ## 网络结构。本次实验采用类AlexNet的网络结构，网络基本单元为[卷积-Relu-池化]，采用全连接层输出
# ![image.png](attachment:8b8a6781-dfbf-4502-b4ba-761479ee66f7.png)

# %% [markdown]
# 1. 浅：AletNet_deeps

# %%
class AlexNet_deepS(nn.Module):
    def  __init__(self):
        super().__init__()
        self.conv1 = nn.Sequential(
            nn.Conv2d(3,6,3,padding = 1),
            nn.ReLU(),
            nn.MaxPool2d(2,2)
            #输入3*32*32，,输出6*16*16
        )
        self.conv2 = nn.Sequential(
            nn.Conv2d(6,16,3,padding = 1),#(16-3+2)/1+1 = 16
            nn.ReLU(),
            nn.MaxPool2d(2,2)
            #输入6*16*16，输出16*8*8
        )
        self.fc1 = nn.Linear(16*8*8,120)
        self.fc2 = nn.Linear(120,10)
    def forward(self,x):
        in_size = x.size(0)
        out = self.conv1(x)
        out = self.conv2(out)
        out = out.view(-1,16*8*8)
        out = self.fc1(out)
        out = F.relu(out)
        out = self.fc2(out)
        return out

# %% [markdown]
# 2. 中：AlexNet_deepm

# %%
class AlexNet_deepM(nn.Module):
    def  __init__(self):
        super().__init__()
        self.conv1 = nn.Sequential(
            nn.Conv2d(3,6,3,padding = 1),
            nn.ReLU(),
            nn.MaxPool2d(2,2)
            #输入3*32*32，,输出6*16*16
        )
        self.conv2 = nn.Sequential(
            nn.Conv2d(6,16,3,padding = 1),#(16-3+2)/1+1 = 16
            nn.ReLU(),
            nn.MaxPool2d(2,2)
            #输入6*16*16，输出16*8*8
        )
        self.conv3 = nn.Sequential(
            nn.Conv2d(16,32,3,padding = 1),#(8-3+2)/1+1 = 8
            nn.ReLU(),
            nn.MaxPool2d(2,2)
            #输入16*8*8，输出32*4*4
        )
        self.fc1 = nn.Linear(32*4*4,120)
        self.fc2 = nn.Linear(120,60)
        self.fc3 = nn.Linear(60,10)
    def forward(self,x):
        in_size = x.size(0)
        out = self.conv1(x)
        out = self.conv2(out)
        out = self.conv3(out)
        out = out.view(-1,32*4*4)
        out = self.fc1(out)
        out = F.relu(out)
        out = self.fc2(out)
        out = F.relu(out)
        out = self.fc3(out)
        return out

# %% [markdown]
# 3. 深：AlexNet_deepd

# %%
class AlexNet_deepD(nn.Module):
    def __init__(self):
        super().__init__()
        self.conv1 = nn.Sequential(
            nn.Conv2d(3,6,3,padding = 1),#（32-3+2）/1+1 = 32
            nn.ReLU(),
            nn.MaxPool2d(2,2)
            #输入3*32*32，,输出6*16*16
        )
        self.conv2 = nn.Sequential(
            nn.Conv2d(6,16,3,padding = 1),#(16-3+2)/1+1 = 16
            nn.ReLU(),
            nn.MaxPool2d(2,2)
            #输入6*16*16，输出16*8*8
        )
        self.conv3 = nn.Sequential(
            nn.Conv2d(16,32,3,padding = 1),#(8-3+2)/1+1 = 8
            nn.ReLU(),
            nn.MaxPool2d(2,2)
            #输入16*8*8，输出32*4*4
        )
        self.conv4 = nn.Sequential(
            nn.Conv2d(32,64,3,padding = 1),#4-3+2/1+1 = 4
            nn.ReLU(),
            nn.MaxPool2d(2,2)
            #输入32*4*4，输出64*2*2
        )
        self.conv5 = nn.Sequential(
            nn.Conv2d(64,128,3,padding = 1), #2-3+2+1 = 2
            nn.ReLU(),
            nn.MaxPool2d(2,2)
        )
        self.fc1 = nn.Linear(128,120)
        self.fc2 = nn.Linear(120,60)
        self.fc3 = nn.Linear(60,10)
    def forward(self,x):
        in_size = x.size(0)
        out = self.conv1(x)
        out = self.conv2(out)
        out = self.conv3(out)
        out = self.conv4(out)
        out = self.conv5(out)
        #out = out.view(in_size,-1)
        out = out.view(-1,128)
        out = self.fc1(out)
        out = F.relu(out)
        out = self.fc2(out)
        out = F.relu(out)
        out = self.fc3(out)
        return out

# %% [markdown]
# ## 训练与测试

# %%
net_deepS = AlexNet_deepS().to(DEVICE)
net_deepM = AlexNet_deepM().to(DEVICE)
net_deepD = AlexNet_deepD().to(DEVICE)

# %%
#交叉熵损失函数，Adam优化器
criterion = nn.CrossEntropyLoss()
optimizer_S = optim.Adam(net_deepS.parameters())
optimizer_M = optim.Adam(net_deepM.parameters())
optimizer_D = optim.Adam(net_deepD.parameters())

# %%
#定义一些list，用于存储LOSS和ACCURACY
LOSS_S,LOSS_M,LOSS_D = [],[],[]
ACC_S,ACC_M,ACC_D = [],[],[]

# %%
#训练与测试-浅
for epoch in range(EPOCH):
    train(net_deepS,DEVICE,train_loader,optimizer_S,epoch,LOSS_S)
    test(net_deepS,DEVICE,test_loader,ACC_S)
# Out:
# Trian Epoch 0 25000 / 50000 LOSS:1.5182
# Trian Epoch 0 50000 / 50000 LOSS:1.3277
# Accuracy on test iamges:49.650%
# Trian Epoch 1 25000 / 50000 LOSS:1.2186
# Trian Epoch 1 50000 / 50000 LOSS:1.2369
# Accuracy on test iamges:54.810%
# Trian Epoch 2 25000 / 50000 LOSS:1.1428
# Trian Epoch 2 50000 / 50000 LOSS:1.1891
# Accuracy on test iamges:59.260%
# Trian Epoch 3 25000 / 50000 LOSS:1.0424
# Trian Epoch 3 50000 / 50000 LOSS:0.9567
# Accuracy on test iamges:61.250%
# Trian Epoch 4 25000 / 50000 LOSS:0.9961
# Trian Epoch 4 50000 / 50000 LOSS:1.1091
# Accuracy on test iamges:61.450%
# Trian Epoch 5 25000 / 50000 LOSS:0.9325
# Trian Epoch 5 50000 / 50000 LOSS:1.0265
# Accuracy on test iamges:62.890%
# Trian Epoch 6 25000 / 50000 LOSS:0.9360
# Trian Epoch 6 50000 / 50000 LOSS:0.9480
# Accuracy on test iamges:63.480%
# Trian Epoch 7 25000 / 50000 LOSS:0.8685
# Trian Epoch 7 50000 / 50000 LOSS:0.9016
# Accuracy on test iamges:64.260%
# Trian Epoch 8 25000 / 50000 LOSS:0.8777
# Trian Epoch 8 50000 / 50000 LOSS:0.8925
# Accuracy on test iamges:63.730%
# Trian Epoch 9 25000 / 50000 LOSS:0.8278
# Trian Epoch 9 50000 / 50000 LOSS:0.9011
# Accuracy on test iamges:63.920%
# Trian Epoch 10 25000 / 50000 LOSS:0.8886
# Trian Epoch 10 50000 / 50000 LOSS:0.8979
# Accuracy on test iamges:64.820%
# Trian Epoch 11 25000 / 50000 LOSS:0.7811
# Trian Epoch 11 50000 / 50000 LOSS:0.8007
# Accuracy on test iamges:65.090%
# Trian Epoch 12 25000 / 50000 LOSS:0.7691
# Trian Epoch 12 50000 / 50000 LOSS:0.7570
# Accuracy on test iamges:64.620%
# Trian Epoch 13 25000 / 50000 LOSS:0.6945
# Trian Epoch 13 50000 / 50000 LOSS:0.7991
# Accuracy on test iamges:65.050%
# Trian Epoch 14 25000 / 50000 LOSS:0.6221
# Trian Epoch 14 50000 / 50000 LOSS:0.6796
# Accuracy on test iamges:65.280%
# Trian Epoch 15 25000 / 50000 LOSS:0.6799
# Trian Epoch 15 50000 / 50000 LOSS:0.6367
# Accuracy on test iamges:65.240%
# Trian Epoch 16 25000 / 50000 LOSS:0.6402
# Trian Epoch 16 50000 / 50000 LOSS:0.6385
# Accuracy on test iamges:65.080%
# Trian Epoch 17 25000 / 50000 LOSS:0.5659
# Trian Epoch 17 50000 / 50000 LOSS:0.6037
# Accuracy on test iamges:64.920%
# Trian Epoch 18 25000 / 50000 LOSS:0.5477
# Trian Epoch 18 50000 / 50000 LOSS:0.5361
# Accuracy on test iamges:65.160%
# Trian Epoch 19 25000 / 50000 LOSS:0.5945
# Trian Epoch 19 50000 / 50000 LOSS:0.5171
# Accuracy on test iamges:64.960%
# Trian Epoch 20 25000 / 50000 LOSS:0.5879
# Trian Epoch 20 50000 / 50000 LOSS:0.5442
# Accuracy on test iamges:64.850%
# Trian Epoch 21 25000 / 50000 LOSS:0.5229
# Trian Epoch 21 50000 / 50000 LOSS:0.6569
# Accuracy on test iamges:64.240%
# Trian Epoch 22 25000 / 50000 LOSS:0.4924
# Trian Epoch 22 50000 / 50000 LOSS:0.5243
# Accuracy on test iamges:64.270%
# Trian Epoch 23 25000 / 50000 LOSS:0.3552
# Trian Epoch 23 50000 / 50000 LOSS:0.5718
# Accuracy on test iamges:63.750%
# Trian Epoch 24 25000 / 50000 LOSS:0.4579
# Trian Epoch 24 50000 / 50000 LOSS:0.5297
# Accuracy on test iamges:63.760%
# Trian Epoch 25 25000 / 50000 LOSS:0.3630
# Trian Epoch 25 50000 / 50000 LOSS:0.4292
# Accuracy on test iamges:63.910%
# Trian Epoch 26 25000 / 50000 LOSS:0.4005
# Trian Epoch 26 50000 / 50000 LOSS:0.3452
# Accuracy on test iamges:63.540%
# Trian Epoch 27 25000 / 50000 LOSS:0.2994
# Trian Epoch 27 50000 / 50000 LOSS:0.3680
# Accuracy on test iamges:63.900%
# Trian Epoch 28 25000 / 50000 LOSS:0.2937
# Trian Epoch 28 50000 / 50000 LOSS:0.3253
# Accuracy on test iamges:63.420%
# Trian Epoch 29 25000 / 50000 LOSS:0.3581
# Trian Epoch 29 50000 / 50000 LOSS:0.4494
# Accuracy on test iamges:63.850%
# Trian Epoch 30 25000 / 50000 LOSS:0.2853
# Trian Epoch 30 50000 / 50000 LOSS:0.2728
# Accuracy on test iamges:63.020%
# Trian Epoch 31 25000 / 50000 LOSS:0.2718
# Trian Epoch 31 50000 / 50000 LOSS:0.2238
# Accuracy on test iamges:62.970%
# Trian Epoch 32 25000 / 50000 LOSS:0.2708
# Trian Epoch 32 50000 / 50000 LOSS:0.2812
# Accuracy on test iamges:62.800%
# Trian Epoch 33 25000 / 50000 LOSS:0.3059
# Trian Epoch 33 50000 / 50000 LOSS:0.2486
# Accuracy on test iamges:63.310%
# Trian Epoch 34 25000 / 50000 LOSS:0.2636
# Trian Epoch 34 50000 / 50000 LOSS:0.3321
# Accuracy on test iamges:62.580%
# Trian Epoch 35 25000 / 50000 LOSS:0.1902
# Trian Epoch 35 50000 / 50000 LOSS:0.3037
# Accuracy on test iamges:63.030%
# Trian Epoch 36 25000 / 50000 LOSS:0.2627
# Trian Epoch 36 50000 / 50000 LOSS:0.3008
# Accuracy on test iamges:62.410%
# Trian Epoch 37 25000 / 50000 LOSS:0.1983
# Trian Epoch 37 50000 / 50000 LOSS:0.2051
# Accuracy on test iamges:62.670%
# Trian Epoch 38 25000 / 50000 LOSS:0.2307
# Trian Epoch 38 50000 / 50000 LOSS:0.2259
# Accuracy on test iamges:62.490%
# Trian Epoch 39 25000 / 50000 LOSS:0.1615
# Trian Epoch 39 50000 / 50000 LOSS:0.1737
# Accuracy on test iamges:62.570%
# Trian Epoch 40 25000 / 50000 LOSS:0.2057
# Trian Epoch 40 50000 / 50000 LOSS:0.3262
# Accuracy on test iamges:62.410%
# Trian Epoch 41 25000 / 50000 LOSS:0.1767
# Trian Epoch 41 50000 / 50000 LOSS:0.3188
# Accuracy on test iamges:61.920%
# Trian Epoch 42 25000 / 50000 LOSS:0.1475
# Trian Epoch 42 50000 / 50000 LOSS:0.1574
# Accuracy on test iamges:61.560%
# Trian Epoch 43 25000 / 50000 LOSS:0.1686
# Trian Epoch 43 50000 / 50000 LOSS:0.1890
# Accuracy on test iamges:61.900%
# Trian Epoch 44 25000 / 50000 LOSS:0.1121
# Trian Epoch 44 50000 / 50000 LOSS:0.1405
# Accuracy on test iamges:61.870%
# Trian Epoch 45 25000 / 50000 LOSS:0.1082
# Trian Epoch 45 50000 / 50000 LOSS:0.1076
# Accuracy on test iamges:61.490%
# Trian Epoch 46 25000 / 50000 LOSS:0.1311
# Trian Epoch 46 50000 / 50000 LOSS:0.1155
# Accuracy on test iamges:61.800%
# Trian Epoch 47 25000 / 50000 LOSS:0.0964
# Trian Epoch 47 50000 / 50000 LOSS:0.1169
# Accuracy on test iamges:61.710%
# Trian Epoch 48 25000 / 50000 LOSS:0.1317
# Trian Epoch 48 50000 / 50000 LOSS:0.1548
# Accuracy on test iamges:61.360%
# Trian Epoch 49 25000 / 50000 LOSS:0.0550
# Trian Epoch 49 50000 / 50000 LOSS:0.0709
# Accuracy on test iamges:61.350%
# Trian Epoch 50 25000 / 50000 LOSS:0.1417
# Trian Epoch 50 50000 / 50000 LOSS:0.1246
# Accuracy on test iamges:61.550%
# Trian Epoch 51 25000 / 50000 LOSS:0.0974
# Trian Epoch 51 50000 / 50000 LOSS:0.1547
# Accuracy on test iamges:61.180%
# Trian Epoch 52 25000 / 50000 LOSS:0.0890
# Trian Epoch 52 50000 / 50000 LOSS:0.0865
# Accuracy on test iamges:61.630%
# Trian Epoch 53 25000 / 50000 LOSS:0.0966
# Trian Epoch 53 50000 / 50000 LOSS:0.0911
# Accuracy on test iamges:60.730%
# Trian Epoch 54 25000 / 50000 LOSS:0.0686
# Trian Epoch 54 50000 / 50000 LOSS:0.0845
# Accuracy on test iamges:61.180%
# Trian Epoch 55 25000 / 50000 LOSS:0.1130
# Trian Epoch 55 50000 / 50000 LOSS:0.0928
# Accuracy on test iamges:61.050%
# Trian Epoch 56 25000 / 50000 LOSS:0.0582
# Trian Epoch 56 50000 / 50000 LOSS:0.0789
# Accuracy on test iamges:60.900%
# Trian Epoch 57 25000 / 50000 LOSS:0.0665
# Trian Epoch 57 50000 / 50000 LOSS:0.0610
# Accuracy on test iamges:61.200%
# Trian Epoch 58 25000 / 50000 LOSS:0.0647
# Trian Epoch 58 50000 / 50000 LOSS:0.1209
# Accuracy on test iamges:61.010%
# Trian Epoch 59 25000 / 50000 LOSS:0.0551
# Trian Epoch 59 50000 / 50000 LOSS:0.0664
# Accuracy on test iamges:61.000%
# Trian Epoch 60 25000 / 50000 LOSS:0.0612
# Trian Epoch 60 50000 / 50000 LOSS:0.0783
# Accuracy on test iamges:60.970%
# Trian Epoch 61 25000 / 50000 LOSS:0.0863
# Trian Epoch 61 50000 / 50000 LOSS:0.0762
# Accuracy on test iamges:60.630%
# Trian Epoch 62 25000 / 50000 LOSS:0.0814
# Trian Epoch 62 50000 / 50000 LOSS:0.0797
# Accuracy on test iamges:60.580%
# Trian Epoch 63 25000 / 50000 LOSS:0.1090
# Trian Epoch 63 50000 / 50000 LOSS:0.1017
# Accuracy on test iamges:60.810%
# Trian Epoch 64 25000 / 50000 LOSS:0.0410
# Trian Epoch 64 50000 / 50000 LOSS:0.0793
# Accuracy on test iamges:61.380%
# Trian Epoch 65 25000 / 50000 LOSS:0.0194
# Trian Epoch 65 50000 / 50000 LOSS:0.0723
# Accuracy on test iamges:61.080%
# Trian Epoch 66 25000 / 50000 LOSS:0.0510
# Trian Epoch 66 50000 / 50000 LOSS:0.0397
# Accuracy on test iamges:60.840%
# Trian Epoch 67 25000 / 50000 LOSS:0.0140
# Trian Epoch 67 50000 / 50000 LOSS:0.0407
# Accuracy on test iamges:61.590%
# Trian Epoch 68 25000 / 50000 LOSS:0.0442
# Trian Epoch 68 50000 / 50000 LOSS:0.0766
# Accuracy on test iamges:60.620%
# Trian Epoch 69 25000 / 50000 LOSS:0.0727
# Trian Epoch 69 50000 / 50000 LOSS:0.1762
# Accuracy on test iamges:61.390%
# Trian Epoch 70 25000 / 50000 LOSS:0.0478
# Trian Epoch 70 50000 / 50000 LOSS:0.0651
# Accuracy on test iamges:61.170%
# Trian Epoch 71 25000 / 50000 LOSS:0.0426
# Trian Epoch 71 50000 / 50000 LOSS:0.0501
# Accuracy on test iamges:60.570%
# Trian Epoch 72 25000 / 50000 LOSS:0.0369
# Trian Epoch 72 50000 / 50000 LOSS:0.0410
# Accuracy on test iamges:60.960%
# Trian Epoch 73 25000 / 50000 LOSS:0.0303
# Trian Epoch 73 50000 / 50000 LOSS:0.0715
# Accuracy on test iamges:60.450%
# Trian Epoch 74 25000 / 50000 LOSS:0.1111
# Trian Epoch 74 50000 / 50000 LOSS:0.0995
# Accuracy on test iamges:61.090%

# %%
#训练与测试-中
for epoch in range(EPOCH):
    train(net_deepM,DEVICE,train_loader,optimizer_M,epoch,LOSS_M)
    test(net_deepM,DEVICE,test_loader,ACC_M)
# Out:
# Trian Epoch 0 25000 / 50000 LOSS:1.6743
# Trian Epoch 0 50000 / 50000 LOSS:1.6056
# Accuracy on test iamges:43.770%
# Trian Epoch 1 25000 / 50000 LOSS:1.4170
# Trian Epoch 1 50000 / 50000 LOSS:1.5387
# Accuracy on test iamges:49.380%
# Trian Epoch 2 25000 / 50000 LOSS:1.3869
# Trian Epoch 2 50000 / 50000 LOSS:1.3402
# Accuracy on test iamges:53.410%
# Trian Epoch 3 25000 / 50000 LOSS:1.1911
# Trian Epoch 3 50000 / 50000 LOSS:1.1302
# Accuracy on test iamges:54.420%
# Trian Epoch 4 25000 / 50000 LOSS:1.1288
# Trian Epoch 4 50000 / 50000 LOSS:1.2226
# Accuracy on test iamges:56.720%
# Trian Epoch 5 25000 / 50000 LOSS:1.1201
# Trian Epoch 5 50000 / 50000 LOSS:0.9226
# Accuracy on test iamges:59.550%
# Trian Epoch 6 25000 / 50000 LOSS:1.0373
# Trian Epoch 6 50000 / 50000 LOSS:0.8746
# Accuracy on test iamges:60.540%
# Trian Epoch 7 25000 / 50000 LOSS:1.1981
# Trian Epoch 7 50000 / 50000 LOSS:1.0182
# Accuracy on test iamges:62.630%
# Trian Epoch 8 25000 / 50000 LOSS:0.8986
# Trian Epoch 8 50000 / 50000 LOSS:0.9470
# Accuracy on test iamges:63.710%
# Trian Epoch 9 25000 / 50000 LOSS:0.9412
# Trian Epoch 9 50000 / 50000 LOSS:0.9530
# Accuracy on test iamges:63.610%
# Trian Epoch 10 25000 / 50000 LOSS:0.9310
# Trian Epoch 10 50000 / 50000 LOSS:0.9191
# Accuracy on test iamges:64.190%
# Trian Epoch 11 25000 / 50000 LOSS:0.9368
# Trian Epoch 11 50000 / 50000 LOSS:0.8710
# Accuracy on test iamges:65.030%
# Trian Epoch 12 25000 / 50000 LOSS:0.8634
# Trian Epoch 12 50000 / 50000 LOSS:0.8830
# Accuracy on test iamges:65.780%
# Trian Epoch 13 25000 / 50000 LOSS:0.8413
# Trian Epoch 13 50000 / 50000 LOSS:0.9049
# Accuracy on test iamges:66.010%
# Trian Epoch 14 25000 / 50000 LOSS:0.7506
# Trian Epoch 14 50000 / 50000 LOSS:0.8756
# Accuracy on test iamges:66.850%
# Trian Epoch 15 25000 / 50000 LOSS:0.6892
# Trian Epoch 15 50000 / 50000 LOSS:0.7530
# Accuracy on test iamges:66.180%
# Trian Epoch 16 25000 / 50000 LOSS:0.7944
# Trian Epoch 16 50000 / 50000 LOSS:0.7046
# Accuracy on test iamges:67.950%
# Trian Epoch 17 25000 / 50000 LOSS:0.6869
# Trian Epoch 17 50000 / 50000 LOSS:0.8204
# Accuracy on test iamges:67.450%
# Trian Epoch 18 25000 / 50000 LOSS:0.7452
# Trian Epoch 18 50000 / 50000 LOSS:0.7684
# Accuracy on test iamges:67.660%
# Trian Epoch 19 25000 / 50000 LOSS:0.6679
# Trian Epoch 19 50000 / 50000 LOSS:0.6928
# Accuracy on test iamges:67.930%
# Trian Epoch 20 25000 / 50000 LOSS:0.6715
# Trian Epoch 20 50000 / 50000 LOSS:0.6318
# Accuracy on test iamges:67.960%
# Trian Epoch 21 25000 / 50000 LOSS:0.7930
# Trian Epoch 21 50000 / 50000 LOSS:0.6713
# Accuracy on test iamges:68.150%
# Trian Epoch 22 25000 / 50000 LOSS:0.5880
# Trian Epoch 22 50000 / 50000 LOSS:0.7619
# Accuracy on test iamges:68.520%
# Trian Epoch 23 25000 / 50000 LOSS:0.5591
# Trian Epoch 23 50000 / 50000 LOSS:0.5971
# Accuracy on test iamges:68.190%
# Trian Epoch 24 25000 / 50000 LOSS:0.6678
# Trian Epoch 24 50000 / 50000 LOSS:0.5428
# Accuracy on test iamges:69.280%
# Trian Epoch 25 25000 / 50000 LOSS:0.6934
# Trian Epoch 25 50000 / 50000 LOSS:0.5584
# Accuracy on test iamges:68.490%
# Trian Epoch 26 25000 / 50000 LOSS:0.5847
# Trian Epoch 26 50000 / 50000 LOSS:0.6465
# Accuracy on test iamges:67.950%
# Trian Epoch 27 25000 / 50000 LOSS:0.6036
# Trian Epoch 27 50000 / 50000 LOSS:0.5341
# Accuracy on test iamges:68.930%
# Trian Epoch 28 25000 / 50000 LOSS:0.5533
# Trian Epoch 28 50000 / 50000 LOSS:0.7167
# Accuracy on test iamges:68.200%
# Trian Epoch 29 25000 / 50000 LOSS:0.6347
# Trian Epoch 29 50000 / 50000 LOSS:0.5779
# Accuracy on test iamges:68.480%
# Trian Epoch 30 25000 / 50000 LOSS:0.6886
# Trian Epoch 30 50000 / 50000 LOSS:0.6565
# Accuracy on test iamges:67.980%
# Trian Epoch 31 25000 / 50000 LOSS:0.5914
# Trian Epoch 31 50000 / 50000 LOSS:0.6952
# Accuracy on test iamges:67.510%
# Trian Epoch 32 25000 / 50000 LOSS:0.4892
# Trian Epoch 32 50000 / 50000 LOSS:0.6759
# Accuracy on test iamges:67.700%
# Trian Epoch 33 25000 / 50000 LOSS:0.4384
# Trian Epoch 33 50000 / 50000 LOSS:0.6277
# Accuracy on test iamges:67.990%
# Trian Epoch 34 25000 / 50000 LOSS:0.4185
# Trian Epoch 34 50000 / 50000 LOSS:0.5233
# Accuracy on test iamges:68.630%
# Trian Epoch 35 25000 / 50000 LOSS:0.4855
# Trian Epoch 35 50000 / 50000 LOSS:0.6612
# Accuracy on test iamges:68.170%
# Trian Epoch 36 25000 / 50000 LOSS:0.3875
# Trian Epoch 36 50000 / 50000 LOSS:0.5056
# Accuracy on test iamges:68.050%
# Trian Epoch 37 25000 / 50000 LOSS:0.4379
# Trian Epoch 37 50000 / 50000 LOSS:0.4900
# Accuracy on test iamges:67.980%
# Trian Epoch 38 25000 / 50000 LOSS:0.4345
# Trian Epoch 38 50000 / 50000 LOSS:0.4451
# Accuracy on test iamges:67.850%
# Trian Epoch 39 25000 / 50000 LOSS:0.4640
# Trian Epoch 39 50000 / 50000 LOSS:0.3284
# Accuracy on test iamges:67.190%
# Trian Epoch 40 25000 / 50000 LOSS:0.4126
# Trian Epoch 40 50000 / 50000 LOSS:0.4731
# Accuracy on test iamges:67.320%
# Trian Epoch 41 25000 / 50000 LOSS:0.3976
# Trian Epoch 41 50000 / 50000 LOSS:0.4377
# Accuracy on test iamges:67.610%
# Trian Epoch 42 25000 / 50000 LOSS:0.4166
# Trian Epoch 42 50000 / 50000 LOSS:0.4229
# Accuracy on test iamges:67.350%
# Trian Epoch 43 25000 / 50000 LOSS:0.3898
# Trian Epoch 43 50000 / 50000 LOSS:0.4068
# Accuracy on test iamges:67.360%
# Trian Epoch 44 25000 / 50000 LOSS:0.3283
# Trian Epoch 44 50000 / 50000 LOSS:0.3998
# Accuracy on test iamges:67.690%
# Trian Epoch 45 25000 / 50000 LOSS:0.3106
# Trian Epoch 45 50000 / 50000 LOSS:0.4044
# Accuracy on test iamges:67.180%
# Trian Epoch 46 25000 / 50000 LOSS:0.3654
# Trian Epoch 46 50000 / 50000 LOSS:0.4890
# Accuracy on test iamges:67.160%
# Trian Epoch 47 25000 / 50000 LOSS:0.3591
# Trian Epoch 47 50000 / 50000 LOSS:0.2623
# Accuracy on test iamges:67.430%
# Trian Epoch 48 25000 / 50000 LOSS:0.3672
# Trian Epoch 48 50000 / 50000 LOSS:0.3776
# Accuracy on test iamges:67.300%
# Trian Epoch 49 25000 / 50000 LOSS:0.4668
# Trian Epoch 49 50000 / 50000 LOSS:0.3839
# Accuracy on test iamges:66.560%
# Trian Epoch 50 25000 / 50000 LOSS:0.3186
# Trian Epoch 50 50000 / 50000 LOSS:0.4891
# Accuracy on test iamges:66.860%
# Trian Epoch 51 25000 / 50000 LOSS:0.3300
# Trian Epoch 51 50000 / 50000 LOSS:0.3157
# Accuracy on test iamges:67.250%
# Trian Epoch 52 25000 / 50000 LOSS:0.3176
# Trian Epoch 52 50000 / 50000 LOSS:0.2547
# Accuracy on test iamges:66.270%
# Trian Epoch 53 25000 / 50000 LOSS:0.3246
# Trian Epoch 53 50000 / 50000 LOSS:0.4073
# Accuracy on test iamges:66.190%
# Trian Epoch 54 25000 / 50000 LOSS:0.2784
# Trian Epoch 54 50000 / 50000 LOSS:0.4146
# Accuracy on test iamges:66.630%
# Trian Epoch 55 25000 / 50000 LOSS:0.3876
# Trian Epoch 55 50000 / 50000 LOSS:0.2695
# Accuracy on test iamges:67.030%
# Trian Epoch 56 25000 / 50000 LOSS:0.3500
# Trian Epoch 56 50000 / 50000 LOSS:0.3719
# Accuracy on test iamges:66.590%
# Trian Epoch 57 25000 / 50000 LOSS:0.2571
# Trian Epoch 57 50000 / 50000 LOSS:0.3496
# Accuracy on test iamges:66.530%
# Trian Epoch 58 25000 / 50000 LOSS:0.2924
# Trian Epoch 58 50000 / 50000 LOSS:0.2626
# Accuracy on test iamges:66.150%
# Trian Epoch 59 25000 / 50000 LOSS:0.3816
# Trian Epoch 59 50000 / 50000 LOSS:0.4511
# Accuracy on test iamges:65.560%
# Trian Epoch 60 25000 / 50000 LOSS:0.2423
# Trian Epoch 60 50000 / 50000 LOSS:0.2571
# Accuracy on test iamges:66.500%
# Trian Epoch 61 25000 / 50000 LOSS:0.2353
# Trian Epoch 61 50000 / 50000 LOSS:0.2422
# Accuracy on test iamges:66.080%
# Trian Epoch 62 25000 / 50000 LOSS:0.2145
# Trian Epoch 62 50000 / 50000 LOSS:0.3340
# Accuracy on test iamges:66.060%
# Trian Epoch 63 25000 / 50000 LOSS:0.2716
# Trian Epoch 63 50000 / 50000 LOSS:0.3164
# Accuracy on test iamges:65.910%
# Trian Epoch 64 25000 / 50000 LOSS:0.2031
# Trian Epoch 64 50000 / 50000 LOSS:0.5030
# Accuracy on test iamges:65.510%
# Trian Epoch 65 25000 / 50000 LOSS:0.3151
# Trian Epoch 65 50000 / 50000 LOSS:0.1669
# Accuracy on test iamges:65.880%
# Trian Epoch 66 25000 / 50000 LOSS:0.2900
# Trian Epoch 66 50000 / 50000 LOSS:0.2326
# Accuracy on test iamges:65.210%
# Trian Epoch 67 25000 / 50000 LOSS:0.2233
# Trian Epoch 67 50000 / 50000 LOSS:0.2106
# Accuracy on test iamges:65.860%
# Trian Epoch 68 25000 / 50000 LOSS:0.2568
# Trian Epoch 68 50000 / 50000 LOSS:0.3045
# Accuracy on test iamges:65.370%
# Trian Epoch 69 25000 / 50000 LOSS:0.1788
# Trian Epoch 69 50000 / 50000 LOSS:0.2144
# Accuracy on test iamges:65.050%
# Trian Epoch 70 25000 / 50000 LOSS:0.2052
# Trian Epoch 70 50000 / 50000 LOSS:0.2519
# Accuracy on test iamges:65.180%
# Trian Epoch 71 25000 / 50000 LOSS:0.1598
# Trian Epoch 71 50000 / 50000 LOSS:0.2178
# Accuracy on test iamges:65.150%
# Trian Epoch 72 25000 / 50000 LOSS:0.2073
# Trian Epoch 72 50000 / 50000 LOSS:0.3522
# Accuracy on test iamges:65.440%
# Trian Epoch 73 25000 / 50000 LOSS:0.1945
# Trian Epoch 73 50000 / 50000 LOSS:0.2059
# Accuracy on test iamges:65.000%
# Trian Epoch 74 25000 / 50000 LOSS:0.1523
# Trian Epoch 74 50000 / 50000 LOSS:0.1744
# Accuracy on test iamges:64.870%

# %%
#训练与测试-深
for epoch in range(EPOCH):
    train(net_deepD,DEVICE,train_loader,optimizer_D,epoch,LOSS_D)
    test(net_deepD,DEVICE,test_loader,ACC_D)
# Out:
# Trian Epoch 0 25000 / 50000 LOSS:1.8915
# Trian Epoch 0 50000 / 50000 LOSS:1.6817
# Accuracy on test iamges:36.980%
# Trian Epoch 1 25000 / 50000 LOSS:1.5969
# Trian Epoch 1 50000 / 50000 LOSS:1.5122
# Accuracy on test iamges:45.670%
# Trian Epoch 2 25000 / 50000 LOSS:1.3840
# Trian Epoch 2 50000 / 50000 LOSS:1.5366
# Accuracy on test iamges:48.550%
# Trian Epoch 3 25000 / 50000 LOSS:1.3477
# Trian Epoch 3 50000 / 50000 LOSS:1.3311
# Accuracy on test iamges:52.790%
# Trian Epoch 4 25000 / 50000 LOSS:1.2878
# Trian Epoch 4 50000 / 50000 LOSS:1.2373
# Accuracy on test iamges:54.800%
# Trian Epoch 5 25000 / 50000 LOSS:1.3117
# Trian Epoch 5 50000 / 50000 LOSS:1.1532
# Accuracy on test iamges:57.450%
# Trian Epoch 6 25000 / 50000 LOSS:1.1283
# Trian Epoch 6 50000 / 50000 LOSS:1.1977
# Accuracy on test iamges:59.320%
# Trian Epoch 7 25000 / 50000 LOSS:1.1637
# Trian Epoch 7 50000 / 50000 LOSS:0.9586
# Accuracy on test iamges:60.990%
# Trian Epoch 8 25000 / 50000 LOSS:1.0538
# Trian Epoch 8 50000 / 50000 LOSS:0.8756
# Accuracy on test iamges:61.880%
# Trian Epoch 9 25000 / 50000 LOSS:0.8183
# Trian Epoch 9 50000 / 50000 LOSS:0.9549
# Accuracy on test iamges:63.290%
# Trian Epoch 10 25000 / 50000 LOSS:0.9749
# Trian Epoch 10 50000 / 50000 LOSS:0.8394
# Accuracy on test iamges:64.730%
# Trian Epoch 11 25000 / 50000 LOSS:1.0184
# Trian Epoch 11 50000 / 50000 LOSS:0.9598
# Accuracy on test iamges:64.910%
# Trian Epoch 12 25000 / 50000 LOSS:0.8570
# Trian Epoch 12 50000 / 50000 LOSS:0.7674
# Accuracy on test iamges:65.180%
# Trian Epoch 13 25000 / 50000 LOSS:0.9611
# Trian Epoch 13 50000 / 50000 LOSS:0.9957
# Accuracy on test iamges:65.540%
# Trian Epoch 14 25000 / 50000 LOSS:0.9328
# Trian Epoch 14 50000 / 50000 LOSS:0.7075
# Accuracy on test iamges:66.360%
# Trian Epoch 15 25000 / 50000 LOSS:0.6614
# Trian Epoch 15 50000 / 50000 LOSS:0.7237
# Accuracy on test iamges:66.540%
# Trian Epoch 16 25000 / 50000 LOSS:0.6936
# Trian Epoch 16 50000 / 50000 LOSS:0.6068
# Accuracy on test iamges:65.780%
# Trian Epoch 17 25000 / 50000 LOSS:0.6967
# Trian Epoch 17 50000 / 50000 LOSS:0.7251
# Accuracy on test iamges:67.600%
# Trian Epoch 18 25000 / 50000 LOSS:0.7290
# Trian Epoch 18 50000 / 50000 LOSS:0.6783
# Accuracy on test iamges:66.900%
# Trian Epoch 19 25000 / 50000 LOSS:0.6287
# Trian Epoch 19 50000 / 50000 LOSS:0.7360
# Accuracy on test iamges:67.850%
# Trian Epoch 20 25000 / 50000 LOSS:0.7010
# Trian Epoch 20 50000 / 50000 LOSS:0.6068
# Accuracy on test iamges:67.420%
# Trian Epoch 21 25000 / 50000 LOSS:0.6092
# Trian Epoch 21 50000 / 50000 LOSS:0.7294
# Accuracy on test iamges:67.630%
# Trian Epoch 22 25000 / 50000 LOSS:0.5705
# Trian Epoch 22 50000 / 50000 LOSS:0.6371
# Accuracy on test iamges:67.800%
# Trian Epoch 23 25000 / 50000 LOSS:0.5473
# Trian Epoch 23 50000 / 50000 LOSS:0.5937
# Accuracy on test iamges:67.140%
# Trian Epoch 24 25000 / 50000 LOSS:0.5591
# Trian Epoch 24 50000 / 50000 LOSS:0.5257
# Accuracy on test iamges:67.620%
# Trian Epoch 25 25000 / 50000 LOSS:0.4209
# Trian Epoch 25 50000 / 50000 LOSS:0.5649
# Accuracy on test iamges:67.510%
# Trian Epoch 26 25000 / 50000 LOSS:0.6235
# Trian Epoch 26 50000 / 50000 LOSS:0.5068
# Accuracy on test iamges:66.740%
# Trian Epoch 27 25000 / 50000 LOSS:0.5474
# Trian Epoch 27 50000 / 50000 LOSS:0.5253
# Accuracy on test iamges:67.470%
# Trian Epoch 28 25000 / 50000 LOSS:0.3745
# Trian Epoch 28 50000 / 50000 LOSS:0.4365
# Accuracy on test iamges:66.900%
# Trian Epoch 29 25000 / 50000 LOSS:0.4385
# Trian Epoch 29 50000 / 50000 LOSS:0.4850
# Accuracy on test iamges:66.940%
# Trian Epoch 30 25000 / 50000 LOSS:0.3433
# Trian Epoch 30 50000 / 50000 LOSS:0.4850
# Accuracy on test iamges:67.180%
# Trian Epoch 31 25000 / 50000 LOSS:0.3849
# Trian Epoch 31 50000 / 50000 LOSS:0.6479
# Accuracy on test iamges:66.720%
# Trian Epoch 32 25000 / 50000 LOSS:0.3499
# Trian Epoch 32 50000 / 50000 LOSS:0.3597
# Accuracy on test iamges:65.660%
# Trian Epoch 33 25000 / 50000 LOSS:0.3480
# Trian Epoch 33 50000 / 50000 LOSS:0.3819
# Accuracy on test iamges:66.770%
# Trian Epoch 34 25000 / 50000 LOSS:0.4235
# Trian Epoch 34 50000 / 50000 LOSS:0.4960
# Accuracy on test iamges:66.520%
# Trian Epoch 35 25000 / 50000 LOSS:0.2981
# Trian Epoch 35 50000 / 50000 LOSS:0.3695
# Accuracy on test iamges:66.150%
# Trian Epoch 36 25000 / 50000 LOSS:0.2786
# Trian Epoch 36 50000 / 50000 LOSS:0.4750
# Accuracy on test iamges:66.290%
# Trian Epoch 37 25000 / 50000 LOSS:0.3646
# Trian Epoch 37 50000 / 50000 LOSS:0.3272
# Accuracy on test iamges:65.750%
# Trian Epoch 38 25000 / 50000 LOSS:0.3203
# Trian Epoch 38 50000 / 50000 LOSS:0.4967
# Accuracy on test iamges:66.540%
# Trian Epoch 39 25000 / 50000 LOSS:0.2304
# Trian Epoch 39 50000 / 50000 LOSS:0.2345
# Accuracy on test iamges:66.270%
# Trian Epoch 40 25000 / 50000 LOSS:0.3159
# Trian Epoch 40 50000 / 50000 LOSS:0.2867
# Accuracy on test iamges:66.100%
# Trian Epoch 41 25000 / 50000 LOSS:0.1804
# Trian Epoch 41 50000 / 50000 LOSS:0.2667
# Accuracy on test iamges:66.500%
# Trian Epoch 42 25000 / 50000 LOSS:0.2174
# Trian Epoch 42 50000 / 50000 LOSS:0.3827
# Accuracy on test iamges:66.200%
# Trian Epoch 43 25000 / 50000 LOSS:0.3327
# Trian Epoch 43 50000 / 50000 LOSS:0.2084
# Accuracy on test iamges:66.830%
# Trian Epoch 44 25000 / 50000 LOSS:0.2496
# Trian Epoch 44 50000 / 50000 LOSS:0.1971
# Accuracy on test iamges:65.810%
# Trian Epoch 45 25000 / 50000 LOSS:0.2928
# Trian Epoch 45 50000 / 50000 LOSS:0.2029
# Accuracy on test iamges:65.610%
# Trian Epoch 46 25000 / 50000 LOSS:0.2498
# Trian Epoch 46 50000 / 50000 LOSS:0.2616
# Accuracy on test iamges:65.410%
# Trian Epoch 47 25000 / 50000 LOSS:0.2296
# Trian Epoch 47 50000 / 50000 LOSS:0.2948
# Accuracy on test iamges:66.240%
# Trian Epoch 48 25000 / 50000 LOSS:0.3082
# Trian Epoch 48 50000 / 50000 LOSS:0.1700
# Accuracy on test iamges:65.690%
# Trian Epoch 49 25000 / 50000 LOSS:0.1517
# Trian Epoch 49 50000 / 50000 LOSS:0.2770
# Accuracy on test iamges:65.440%
# Trian Epoch 50 25000 / 50000 LOSS:0.1361
# Trian Epoch 50 50000 / 50000 LOSS:0.2109
# Accuracy on test iamges:64.760%
# Trian Epoch 51 25000 / 50000 LOSS:0.1318
# Trian Epoch 51 50000 / 50000 LOSS:0.1898
# Accuracy on test iamges:65.250%
# Trian Epoch 52 25000 / 50000 LOSS:0.1955
# Trian Epoch 52 50000 / 50000 LOSS:0.3764
# Accuracy on test iamges:65.430%
# Trian Epoch 53 25000 / 50000 LOSS:0.1866
# Trian Epoch 53 50000 / 50000 LOSS:0.2150
# Accuracy on test iamges:65.890%
# Trian Epoch 54 25000 / 50000 LOSS:0.1494
# Trian Epoch 54 50000 / 50000 LOSS:0.2172
# Accuracy on test iamges:65.950%
# Trian Epoch 55 25000 / 50000 LOSS:0.1010
# Trian Epoch 55 50000 / 50000 LOSS:0.2218
# Accuracy on test iamges:65.220%
# Trian Epoch 56 25000 / 50000 LOSS:0.2755
# Trian Epoch 56 50000 / 50000 LOSS:0.2255
# Accuracy on test iamges:65.230%
# Trian Epoch 57 25000 / 50000 LOSS:0.0686
# Trian Epoch 57 50000 / 50000 LOSS:0.1575
# Accuracy on test iamges:64.870%
# Trian Epoch 58 25000 / 50000 LOSS:0.1524
# Trian Epoch 58 50000 / 50000 LOSS:0.1597
# Accuracy on test iamges:65.570%
# Trian Epoch 59 25000 / 50000 LOSS:0.0828
# Trian Epoch 59 50000 / 50000 LOSS:0.0838
# Accuracy on test iamges:65.500%
# Trian Epoch 60 25000 / 50000 LOSS:0.1563
# Trian Epoch 60 50000 / 50000 LOSS:0.1251
# Accuracy on test iamges:64.980%
# Trian Epoch 61 25000 / 50000 LOSS:0.1254
# Trian Epoch 61 50000 / 50000 LOSS:0.1813
# Accuracy on test iamges:64.700%
# Trian Epoch 62 25000 / 50000 LOSS:0.1326
# Trian Epoch 62 50000 / 50000 LOSS:0.1516
# Accuracy on test iamges:64.600%
# Trian Epoch 63 25000 / 50000 LOSS:0.1581
# Trian Epoch 63 50000 / 50000 LOSS:0.1215
# Accuracy on test iamges:64.910%
# Trian Epoch 64 25000 / 50000 LOSS:0.0879
# Trian Epoch 64 50000 / 50000 LOSS:0.1270
# Accuracy on test iamges:65.030%
# Trian Epoch 65 25000 / 50000 LOSS:0.1395
# Trian Epoch 65 50000 / 50000 LOSS:0.1788
# Accuracy on test iamges:65.130%
# Trian Epoch 66 25000 / 50000 LOSS:0.1462
# Trian Epoch 66 50000 / 50000 LOSS:0.1464
# Accuracy on test iamges:65.710%
# Trian Epoch 67 25000 / 50000 LOSS:0.1122
# Trian Epoch 67 50000 / 50000 LOSS:0.1218
# Accuracy on test iamges:65.340%
# Trian Epoch 68 25000 / 50000 LOSS:0.0973
# Trian Epoch 68 50000 / 50000 LOSS:0.1823
# Accuracy on test iamges:65.390%
# Trian Epoch 69 25000 / 50000 LOSS:0.0548
# Trian Epoch 69 50000 / 50000 LOSS:0.0791
# Accuracy on test iamges:64.700%
# Trian Epoch 70 25000 / 50000 LOSS:0.0995
# Trian Epoch 70 50000 / 50000 LOSS:0.1427
# Accuracy on test iamges:64.610%
# Trian Epoch 71 25000 / 50000 LOSS:0.0721
# Trian Epoch 71 50000 / 50000 LOSS:0.1537
# Accuracy on test iamges:64.790%
# Trian Epoch 72 25000 / 50000 LOSS:0.1181
# Trian Epoch 72 50000 / 50000 LOSS:0.1088
# Accuracy on test iamges:65.340%
# Trian Epoch 73 25000 / 50000 LOSS:0.1142
# Trian Epoch 73 50000 / 50000 LOSS:0.1722
# Accuracy on test iamges:65.160%
# Trian Epoch 74 25000 / 50000 LOSS:0.0780
# Trian Epoch 74 50000 / 50000 LOSS:0.1912
# Accuracy on test iamges:64.760%

# %% [markdown]
# ## 结果绘图分析

# %%
import numpy as np
plt.rcParams['font.sans-serif']=['SimHei']

# %% [markdown]
# ### 所有循环的LOSS曲线

# %%
xloss = np.arange(0,len(LOSS_S))

# %%
plt.xlabel("iter")
plt.ylabel("LOSS")
plt.plot(xloss,LOSS_S,label = "浅",c='r',alpha = 0.2)
plt.plot(xloss,LOSS_M,label = "中",c='g',alpha = 0.2)
plt.plot(xloss,LOSS_D,label = "深",c='b',alpha = 0.2)
plt.legend()
plt.savefig("deepth_LOSS1.jpg")

# %% [markdown]
# ### 所有epoch的LOSS曲线

# %%
#计算每个epoch的平均LOSS
ls,lm,ld = [],[],[]
step = 250 #每个epoch有250个LOSS
for i in range(EPOCH):
    ls.append(np.mean(LOSS_S[int(i*step):int((i+1)*step-1)]))
    lm.append(np.mean(LOSS_M[int(i*step):int((i+1)*step-1)]))
    ld.append(np.mean(LOSS_D[int(i*step):int((i+1)*step-1)]))

# %%
xloss2 = np.arange(0,len(ls))

# %%
plt.xlabel("EPOCH")
plt.ylabel("LOSS")
plt.plot(xloss2,ls,label = "浅")
plt.plot(xloss2,lm,label = "中")
plt.plot(xloss2,ld,label = "深")
plt.legend()
plt.savefig("deepth_LOSS2.jpg")

# %% [markdown]
# ### 测试集精度

# %%
xac = np.arange(0,len(ACC_S))

# %%
plt.xlabel("EPOCH")
plt.ylabel("VAL_AC")
plt.plot(xac,ACC_S,label = "浅")
plt.plot(xac,ACC_M,label = "中")
plt.plot(xac,ACC_D,label = "深")
plt.legend()
plt.savefig("deepth_ACC.jpg")
